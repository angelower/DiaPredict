# %% [markdown]
#     predicciones_clinicas/
#     │
#     ├── diabetes_app/
#     │   ├── migrations/
#     │   │   └── __init__.py
#     │   ├── __init__.py
#     │   ├── admin.py
#     │   ├── apps.py
#     │   ├── models.py
#     │   ├── views.py
#     │   ├── urls.py
#     │   ├── forms.py
#     │   ├── templates/
#     │   │   └── diabetes/
#     │   │       ├── base.html
#     │   │       ├── formulario.html
#     │   │       └── resultado.html
#     │   └── ml/
#     │       ├── __init__.py
#     │       ├── entrenar_modelo.py
#     │       └── modelo_diabetes.pkl
#     │
#     ├── hipertension_app/
#     │   ├── migrations/
#     │   │   └── __init__.py
#     │   ├── __init__.py
#     │   ├── admin.py
#     │   ├── apps.py
#     │   ├── models.py
#     │   ├── views.py
#     │   ├── urls.py
#     │   ├── forms.py
#     │   ├── templates/
#     │   │   └── hipertension/
#     │   │       ├── base.html
#     │   │       ├── formulario.html
#     │   │       └── resultado.html
#     │   └── ml/
#     │       ├── __init__.py
#     │       ├── entrenar_modelo.py
#     │       └── modelo_hipertension.pkl
#     │
#     ├── covid_app/
#     │   ├── migrations/
#     │   │   └── __init__.py
#     │   ├── __init__.py
#     │   ├── admin.py
#     │   ├── apps.py
#     │   ├── models.py
#     │   ├── views.py
#     │   ├── urls.py
#     │   ├── forms.py
#     │   ├── templates/
#     │   │   └── covid/
#     │   │       ├── base.html
#     │   │       ├── formulario.html
#     │   │       └── resultado.html
#     │   └── ml/
#     │       ├── __init__.py
#     │       ├── entrenar_modelo.py
#     │       └── modelo_covid.pkl
#     │
#     ├── predicciones_clinicas/          # Configuración principal del proyecto
#     │   ├── __init__.py
#     │   ├── settings.py
#     │   ├── urls.py                      # URL principal que incluye las 3 apps
#     │   ├── wsgi.py
#     │   └── asgi.py
#     │
#     ├── templates/                       # Templates globales (opcional)
#     │   └── base_global.html             # Plantilla base común para todas las apps
#     │
#     ├── static/                          # Archivos estáticos globales
#     │   ├── css/
#     │   ├── js/
#     │   └── img/
#     │
#     ├── media/                           # Archivos subidos por usuarios
#     │
#     ├── manage.py
#     ├── requirements.txt
#     └── README.md
